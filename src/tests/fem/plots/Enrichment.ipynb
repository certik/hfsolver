# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Enrichment

# %%
D = loadtxt("../enrichment.txt", skiprows=1)
xn = D[0, :]
Vn = D[1, :]
for i in range(2, 6):
    psi = D[i, :]
    plot(xn, psi)
    print i, psi[:3]
show()
# Out:
# 2 [ 0.  0.  0.]
# 3 [ 0.  0.  0.]
# 4 [ 0.  0.  0.]
# 5 [ 0.  0.  0.]

# %%
plot(xn, Vn)

# %% [markdown]
# # Solutions

# %%
D = loadtxt("../wfn.txt", skiprows=0)
xn = D[0, :]
for i in range(1, 3):
    psi = D[i, :]
    plot(xn, psi)
show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-2aba5000fa59> in <module>()
# ----> 1 D = loadtxt("../wfn.txt", skiprows=0)
#       2 xn = D[0, :]
#       3 for i in range(1, 3):
#       4     psi = D[i, :]
#       5     plot(xn, psi)
#
# /home/certik/ext/miniconda2/envs/jup/lib/python2.7/site-packages/numpy/lib/npyio.pyc in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     925                 line_num = i + skiprows + 1
#     926                 raise ValueError("Wrong number of columns at line %d"
# --> 927                                  % line_num)
#     928
#     929             # Convert each value according to its column and store
#
# ValueError: Wrong number of columns at line 2

# %%
# %%file a.tmp
#     0.0213    0.0550    0.0000
#     0.0550    0.4637    0.0550
#     0.0000    0.0550    0.0213
# Out:
# Overwriting a.tmp

# %%
a = loadtxt("../B.txt")
print svd(a[:8,:8])[1]
print svd(a)[1]
print eig(a)[0]
# Out:
# [ 1.    0.9   0.9   0.67  0.67  0.43  0.43  0.33]
# [ 1.22  0.96  0.9   0.74  0.67  0.5   0.43  0.35  0.03]
# [ 1.22  0.03  0.96  0.74  0.35  0.5   0.9   0.67  0.43]

# %%
eig(a)
# Out:
# (array([ 0.47697695,  0.0213    ,  0.00802305]),
#  array([[ -1.18978663e-01,   7.07106781e-01,   6.97025163e-01],
#         [ -9.85742439e-01,   1.99008142e-16,  -1.68261238e-01],
#         [ -1.18978663e-01,  -7.07106781e-01,   6.97025163e-01]]))

# %%
D = loadtxt("../wfn.txt", skiprows=0)
xn = D[0, :]
psi = D[1, :]
plot(xn, psi, "x")
show()

# %%
set_printoptions(precision=2)
a
# Out:
# array([[ 0.67,  0.17,  0.  ,  0.  ,  0.  ,  0.  ,  0.  ,  0.17,  0.  ],
#        [ 0.17,  0.67,  0.17,  0.  ,  0.  ,  0.  ,  0.  ,  0.  ,  0.  ],
#        [ 0.  ,  0.17,  0.67,  0.17,  0.  ,  0.  ,  0.  ,  0.  ,  0.  ],
#        [ 0.  ,  0.  ,  0.17,  0.67,  0.17,  0.  ,  0.  ,  0.  ,  0.07],
#        [ 0.  ,  0.  ,  0.  ,  0.17,  0.67,  0.17,  0.  ,  0.  ,  0.52],
#        [ 0.  ,  0.  ,  0.  ,  0.  ,  0.17,  0.67,  0.17,  0.  ,  0.07],
#        [ 0.  ,  0.  ,  0.  ,  0.  ,  0.  ,  0.17,  0.67,  0.17,  0.  ],
#        [ 0.17,  0.  ,  0.  ,  0.  ,  0.  ,  0.  ,  0.17,  0.67,  0.  ],
#        [ 0.  ,  0.  ,  0.  ,  0.07,  0.52,  0.07,  0.  ,  0.  ,  0.47]])
