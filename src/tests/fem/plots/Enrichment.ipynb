# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Enrichment

# %%
D = loadtxt("../enrichment.txt", skiprows=1)
xn = D[0, :]
for i in range(1, 4):
    psi = D[i, :]
    plot(xn, psi)
    print i, psi[:3]
show()
# Out:
# 1 [ 0.  0.  0.]
# 2 [ 0.  0.  0.]
# 3 [ 0.  0.  0.]

# %% [markdown]
# # Solutions

# %%
D = loadtxt("../wfn.txt", skiprows=0)
xn = D[0, :]
for i in range(1, 6):
    psi = D[i, :]
    plot(xn, psi)
show()

# %%
# %%file a.tmp
#     0.0213    0.0550    0.0000
#     0.0550    0.4637    0.0550
#     0.0000    0.0550    0.0213
# Out:
# Overwriting a.tmp

# %%
a = loadtxt("../B.txt")
print svd(a[:40,:40])[1]
print svd(a)[1]
print eig(a)[0]
# Out:
# [ 0.27742919  0.27742919  0.27742919  0.27742919  0.27742919  0.27742919
#   0.27742919  0.27742919  0.27742919  0.27742919  0.27742919  0.27742919
#   0.27742919  0.27742919  0.27742919  0.27742919  0.18923748  0.18923748
#   0.18923748  0.18923748  0.18923748  0.18923748  0.18923748  0.18923748
#   0.18923748  0.18923748  0.18923748  0.18923748  0.18923748  0.18923748
#   0.18923748  0.18923748  0.06666667  0.06666667  0.06666667  0.06666667
#   0.06666667  0.06666667  0.06666667  0.06666667]
# [  6.73726162e-01   2.93724445e-01   2.78164377e-01   2.77429189e-01
#    2.77429189e-01   2.77429189e-01   2.77429189e-01   2.77429189e-01
#    2.77429189e-01   2.77429189e-01   2.77429189e-01   2.77429189e-01
#    2.77429189e-01   2.77429189e-01   2.77429189e-01   2.77429189e-01
#    2.59002552e-01   1.91468343e-01   1.89237699e-01   1.89237478e-01
#    1.89237478e-01   1.89237478e-01   1.89237478e-01   1.89237478e-01
#    1.89237478e-01   1.89237478e-01   1.89237478e-01   1.89237478e-01
#    1.89237478e-01   1.89237478e-01   1.89237478e-01   1.89237478e-01
#    8.40444458e-02   6.66666667e-02   6.66666667e-02   6.66666667e-02
#    6.66666667e-02   6.66666667e-02   6.66666667e-02   6.66666667e-02
#    2.21499316e-17   1.10436968e-17   3.27972458e-18]
# [  6.73726162e-01   8.40444458e-02   2.93724445e-01   2.59002552e-01
#    1.91468343e-01   1.89237478e-01   1.89237699e-01   2.78164377e-01
#    1.94974298e-18   2.77429189e-01   4.30188305e-18   3.62103664e-17
#    6.66666667e-02   2.77429189e-01   2.77429189e-01   2.77429189e-01
#    6.66666667e-02   1.89237478e-01   2.77429189e-01   2.77429189e-01
#    1.89237478e-01   6.66666667e-02   1.89237478e-01   2.77429189e-01
#    2.77429189e-01   1.89237478e-01   6.66666667e-02   1.89237478e-01
#    1.89237478e-01   6.66666667e-02   1.89237478e-01   2.77429189e-01
#    1.89237478e-01   6.66666667e-02   1.89237478e-01   2.77429189e-01
#    2.77429189e-01   1.89237478e-01   6.66666667e-02   1.89237478e-01
#    2.77429189e-01   2.77429189e-01   1.89237478e-01]

# %%
eig(a)
# Out:
# (array([ 0.47697695,  0.0213    ,  0.00802305]),
#  array([[ -1.18978663e-01,   7.07106781e-01,   6.97025163e-01],
#         [ -9.85742439e-01,   1.99008142e-16,  -1.68261238e-01],
#         [ -1.18978663e-01,  -7.07106781e-01,   6.97025163e-01]]))

# %%
D = loadtxt("../wfn.txt", skiprows=0)
xn = D[0, :]
psi = D[1, :]
plot(xn, psi, "x")
show()
