# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
D = loadtxt("../enrichment.txt", skiprows=1)
xn = D[0, :]
for i in range(1, 6):
    psi = D[i, :]
    plot(xn, psi)
    print i, psi[:3]
show()
# Out:
# 1 [  1.78456337e-08   1.89477330e-08   2.88205279e-08]
# 2 [  3.73323581e-19   1.26439918e-07   4.42206757e-07]
# 3 [  4.29027831e-06   4.49375840e-06   6.27194855e-06]
# 4 [  3.81065162e-17   9.24065988e-06   3.13207525e-05]
# 5 [ 0.00018217  0.00018881  0.00024568]

# %%
L = 8
x0 = L/2
r = abs(xn - x0)
rc = 1
h = 1 + 20*(r/rc)**7-70*(r/rc)**6+84*(r/rc)**5-35*(r/rc)**4
h[r>rc] = 0

# %%
plot(xn, psi*h)
plot(xn, psi)
plot(xn, h)
