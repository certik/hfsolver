# %%
from numpy import loadtxt
D = loadtxt("../H.pseudo", skiprows=1)
Z, N, Rcut, Ediff = [float(x) for x in open("../H.pseudo").readline().split()]

# %%
R = D[:, 0]
V = D[:, 1]
R = R*Rcut

# %%
plot(R, -1/R, "r--", lw=2, label="-1/R")
plot(R, -V, label="H.pseudo")
plot(R, -(Z/(2.*Rcut))*(3. - (R/Rcut)**2), label="analytic")
ylim([-5.5, 0])
legend()

# %%
D2 = loadtxt("../RegularizedPotential.dat")

# %%
R = D2[:, 0]
Vr = D2[:, 1]
Zr = D2[:, 2]

# %%
plot(R, Vr)
plot(R, -1/R)
plot(R, -(Z/(2.*Rcut))*(3. - (R/Rcut)**2), label="analytic")
ylim([-5.5, 0])
xlim([0, 0.6])
# Out:
# (0, 0.6)

# %%
Z
# Out:
# 1.0
