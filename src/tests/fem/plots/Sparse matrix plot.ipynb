# %% [markdown]
# # Matrix visualization
#
# The matrix is saved in Fortran using:
# ```fortran
# open(newunit=u, file="matrixA.txt", status="replace")
# write(u, *) Ap
# write(u, *) Aj
# write(u, *) Ax
# close(u)
# ```

# %%
# %pylab inline
from scipy.sparse import csr_matrix
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
f = open("../matrixA.txt")
Ap = fromstring(f.readline(), dtype="int", sep=" ")
Aj = fromstring(f.readline(), dtype="int", sep=" ")
Ax = fromstring(f.readline(), dtype="double", sep=" ")

# %%
A = csr_matrix((Ax, Aj-1, Ap-1)).toarray()

# %%
def showmat(A):
    Arelat = abs(A)/abs(A).max()
    figure(figsize=(16,8))
    subplot(121)
    cmap = cm.pink_r
    im = imshow(Arelat, cmap=cmap, interpolation='nearest', vmin=0, vmax=1)
    title("Matrix $A$ (linear scale)")
    colorbar()
    subplot(122)
    im = imshow(log(Arelat), cmap=cmap, interpolation='nearest', vmin=-12, vmax=1)
    title("Matrix $A$ (log scale)")
    colorbar()
    show()

# %% [markdown]
# ### Matrix $A$
#
# The matrix $A$ in the linear system:
# $$
# A x = b
# $$

# %%
showmat(A)
# Out:
# -c:10: RuntimeWarning: divide by zero encountered in log

# %% [markdown]
# ### Matrix $A^{-1}$
#
# Let's calculate SVD first:

# %%
U, s, V = svd(A)

# %% [markdown]
# Let's verify that $U S V = A$ and that $U^{-1} = U^T$ and $V^{-1} = V^T$:

# %%
print abs(dot(U, dot(diag(s), V))-A).max()
print abs(inv(U)-U.T).max()
print abs(inv(V)-V.T).max()
# Out:
# 1.59872115546e-14
# 4.57966997658e-15
# 5.22498710964e-15

# %% [markdown]
# Let's look at the singular values, you can see that the last one is zero:

# %%
s
# Out:
# array([  3.49853254e+00,   3.39025909e+00,   3.39025909e+00,
#          3.39025909e+00,   3.39025909e+00,   3.39025909e+00,
#          3.39025909e+00,   3.28165669e+00,   3.28165669e+00,
#          3.28165669e+00,   3.28165669e+00,   3.28165669e+00,
#          3.28165669e+00,   3.28165669e+00,   3.28165669e+00,
#          3.28165669e+00,   3.28165669e+00,   3.28165669e+00,
#          3.28165669e+00,   3.17447329e+00,   3.17447329e+00,
#          3.17447329e+00,   3.17447329e+00,   3.17447329e+00,
#          3.17447329e+00,   3.17447329e+00,   3.17447329e+00,
#          2.23305382e+00,   2.23305382e+00,   2.21931437e+00,
#          2.21931437e+00,   2.21931437e+00,   2.21931437e+00,
#          2.21931437e+00,   2.21931437e+00,   2.16543726e+00,
#          2.16543726e+00,   2.16543726e+00,   2.16543726e+00,
#          2.16543726e+00,   2.16543726e+00,   2.16543726e+00,
#          2.16543726e+00,   2.16543726e+00,   2.16543726e+00,
#          2.16543726e+00,   2.16543726e+00,   2.15911007e+00,
#          2.15911007e+00,   2.15911007e+00,   2.15911007e+00,
#          2.15911007e+00,   2.15911007e+00,   2.10098711e+00,
#          2.10098711e+00,   2.10098711e+00,   2.10098711e+00,
#          2.10098711e+00,   2.10098711e+00,   2.10098711e+00,
#          2.10098711e+00,   2.10098711e+00,   2.10098711e+00,
#          2.10098711e+00,   2.10098711e+00,   2.07984383e+00,
#          2.07984383e+00,   2.07984383e+00,   2.07984383e+00,
#          2.07984383e+00,   2.07984383e+00,   2.07984383e+00,
#          2.07984383e+00,   2.07984383e+00,   2.07984383e+00,
#          2.07984383e+00,   2.07984383e+00,   2.07984383e+00,
#          2.07984383e+00,   2.07984383e+00,   2.07984383e+00,
#          1.74389015e+00,   1.74389015e+00,   1.74389015e+00,
#          1.74389015e+00,   1.74389015e+00,   1.74389015e+00,
#          1.74389015e+00,   1.74389015e+00,   1.46799763e+00,
#          1.46799763e+00,   1.46799763e+00,   1.46799763e+00,
#          1.46799763e+00,   1.46799763e+00,   1.46799763e+00,
#          1.46799763e+00,   1.46799763e+00,   1.46799763e+00,
#          1.46799763e+00,   1.46799763e+00,   1.34735107e+00,
#          1.34735107e+00,   1.34735107e+00,   1.34735107e+00,
#          1.34735107e+00,   1.34735107e+00,   1.34735107e+00,
#          1.34735107e+00,   1.34735107e+00,   1.34735107e+00,
#          1.34735107e+00,   1.34735107e+00,   1.31648810e+00,
#          1.31648810e+00,   1.31648810e+00,   1.31648810e+00,
#          1.31648810e+00,   1.31648810e+00,   1.29299568e+00,
#          1.29299568e+00,   1.29299568e+00,   1.29299568e+00,
#          1.29299568e+00,   1.29299568e+00,   1.29299568e+00,
#          1.29299568e+00,   1.29299568e+00,   1.29299568e+00,
#          1.29299568e+00,   1.29299568e+00,   1.29299568e+00,
#          1.29299568e+00,   1.29299568e+00,   1.29299568e+00,
#          1.21915664e+00,   1.21915664e+00,   1.21915664e+00,
#          1.21915664e+00,   1.21915664e+00,   1.21915664e+00,
#          1.10200943e+00,   1.09111165e+00,   1.09111165e+00,
#          1.09111165e+00,   1.09111165e+00,   1.09111165e+00,
#          1.09111165e+00,   1.09111165e+00,   1.09111165e+00,
#          1.09111165e+00,   1.09111165e+00,   1.09111165e+00,
#          1.09111165e+00,   1.03509622e+00,   1.03509622e+00,
#          1.03509622e+00,   1.03509622e+00,   1.03509622e+00,
#          1.03509622e+00,   1.03509622e+00,   1.03509622e+00,
#          1.00645236e+00,   1.00645236e+00,   9.51130038e-01,
#          9.51130038e-01,   9.51130038e-01,   9.51130038e-01,
#          9.51130038e-01,   9.51130038e-01,   8.01636980e-01,
#          8.01636980e-01,   8.01636980e-01,   8.01636980e-01,
#          8.01636980e-01,   8.01636980e-01,   8.01636980e-01,
#          8.01636980e-01,   8.01636980e-01,   8.01636980e-01,
#          8.01636980e-01,   8.01636980e-01,   7.26787249e-01,
#          7.26787249e-01,   7.26787249e-01,   7.26787249e-01,
#          7.26787249e-01,   7.26787249e-01,   7.26787249e-01,
#          7.26787249e-01,   5.74154438e-01,   5.74154438e-01,
#          5.74154438e-01,   5.74154438e-01,   5.74154438e-01,
#          5.74154438e-01,   5.58636409e-01,   5.58636409e-01,
#          5.58636409e-01,   5.58636409e-01,   5.58636409e-01,
#          5.58636409e-01,   5.58636409e-01,   5.58636409e-01,
#          5.58636409e-01,   5.58636409e-01,   5.58636409e-01,
#          5.58636409e-01,   3.93038279e-01,   3.27424296e-01,
#          3.27424296e-01,   3.27424296e-01,   3.27424296e-01,
#          3.27424296e-01,   3.27424296e-01,   9.85463753e-16])

# %% [markdown]
# So the matrix $A$ can't be inverted. But we can calculate the pseudoinverse by inverting all the singular values and leaving the zero be:

# %%
s_inv = 1/s
s_inv[-1] = 0
s_inv
# Out:
# array([ 0.28583413,  0.29496271,  0.29496271,  0.29496271,  0.29496271,
#         0.29496271,  0.29496271,  0.30472414,  0.30472414,  0.30472414,
#         0.30472414,  0.30472414,  0.30472414,  0.30472414,  0.30472414,
#         0.30472414,  0.30472414,  0.30472414,  0.30472414,  0.31501289,
#         0.31501289,  0.31501289,  0.31501289,  0.31501289,  0.31501289,
#         0.31501289,  0.31501289,  0.44781724,  0.44781724,  0.45058961,
#         0.45058961,  0.45058961,  0.45058961,  0.45058961,  0.45058961,
#         0.46180049,  0.46180049,  0.46180049,  0.46180049,  0.46180049,
#         0.46180049,  0.46180049,  0.46180049,  0.46180049,  0.46180049,
#         0.46180049,  0.46180049,  0.46315379,  0.46315379,  0.46315379,
#         0.46315379,  0.46315379,  0.46315379,  0.47596675,  0.47596675,
#         0.47596675,  0.47596675,  0.47596675,  0.47596675,  0.47596675,
#         0.47596675,  0.47596675,  0.47596675,  0.47596675,  0.47596675,
#         0.48080533,  0.48080533,  0.48080533,  0.48080533,  0.48080533,
#         0.48080533,  0.48080533,  0.48080533,  0.48080533,  0.48080533,
#         0.48080533,  0.48080533,  0.48080533,  0.48080533,  0.48080533,
#         0.48080533,  0.57343061,  0.57343061,  0.57343061,  0.57343061,
#         0.57343061,  0.57343061,  0.57343061,  0.57343061,  0.68120001,
#         0.68120001,  0.68120001,  0.68120001,  0.68120001,  0.68120001,
#         0.68120001,  0.68120001,  0.68120001,  0.68120001,  0.68120001,
#         0.68120001,  0.74219706,  0.74219706,  0.74219706,  0.74219706,
#         0.74219706,  0.74219706,  0.74219706,  0.74219706,  0.74219706,
#         0.74219706,  0.74219706,  0.74219706,  0.75959669,  0.75959669,
#         0.75959669,  0.75959669,  0.75959669,  0.75959669,  0.77339779,
#         0.77339779,  0.77339779,  0.77339779,  0.77339779,  0.77339779,
#         0.77339779,  0.77339779,  0.77339779,  0.77339779,  0.77339779,
#         0.77339779,  0.77339779,  0.77339779,  0.77339779,  0.77339779,
#         0.82023915,  0.82023915,  0.82023915,  0.82023915,  0.82023915,
#         0.82023915,  0.90743325,  0.91649649,  0.91649649,  0.91649649,
#         0.91649649,  0.91649649,  0.91649649,  0.91649649,  0.91649649,
#         0.91649649,  0.91649649,  0.91649649,  0.91649649,  0.96609376,
#         0.96609376,  0.96609376,  0.96609376,  0.96609376,  0.96609376,
#         0.96609376,  0.96609376,  0.99358901,  0.99358901,  1.05138095,
#         1.05138095,  1.05138095,  1.05138095,  1.05138095,  1.05138095,
#         1.24744744,  1.24744744,  1.24744744,  1.24744744,  1.24744744,
#         1.24744744,  1.24744744,  1.24744744,  1.24744744,  1.24744744,
#         1.24744744,  1.24744744,  1.37591847,  1.37591847,  1.37591847,
#         1.37591847,  1.37591847,  1.37591847,  1.37591847,  1.37591847,
#         1.74169167,  1.74169167,  1.74169167,  1.74169167,  1.74169167,
#         1.74169167,  1.79007308,  1.79007308,  1.79007308,  1.79007308,
#         1.79007308,  1.79007308,  1.79007308,  1.79007308,  1.79007308,
#         1.79007308,  1.79007308,  1.79007308,  2.54428145,  3.0541411 ,
#         3.0541411 ,  3.0541411 ,  3.0541411 ,  3.0541411 ,  3.0541411 ,  0.        ])

# %%
Apinv = dot(V.T, dot(diag(s_inv), U.T))

# %% [markdown]
# The pseudoinverse is "almost" an inverse --- when multiplied by $A$, the result is close to 1 at diagonal, and close to 0 everywhere else:

# %%
showmat(dot(Apinv, A))

# %% [markdown]
# Here is how the pseudoinverse looks like:

# %%
showmat(Apinv)
