# %% [markdown]
# # Matrix visualization
#
# The matrix is saved in Fortran using:
# ```fortran
# open(newunit=u, file="matrixA.txt", status="replace")
# write(u, *) Ap
# write(u, *) Aj
# write(u, *) Ax
# close(u)
# ```

# %%
# %pylab inline
from scipy.sparse import csr_matrix
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
f = open("../matrixA.txt")
Ap = fromstring(f.readline(), dtype="int", sep=" ")
Aj = fromstring(f.readline(), dtype="int", sep=" ")
Ax = fromstring(f.readline(), dtype="double", sep=" ")

# %%
A = csr_matrix((Ax, Aj-1, Ap-1)).toarray()

# %%
def showmat(A):
    Arelat = abs(A)/abs(A).max()
    figure(figsize=(16,8))
    subplot(121)
    cmap = cm.pink_r
    im = imshow(Arelat, cmap=cmap, interpolation='nearest', vmin=0, vmax=1)
    title("Matrix $A$ (linear scale)")
    colorbar()
    subplot(122)
    im = imshow(log(Arelat), cmap=cmap, interpolation='nearest', vmin=-12, vmax=1)
    title("Matrix $A$ (log scale)")
    colorbar()
    show()

# %% [markdown]
# ### Matrix $A$
#
# The matrix $A$ in the linear system:
# $$
# A x = b
# $$

# %%
showmat(A)
# Out:
# -c:10: RuntimeWarning: divide by zero encountered in log

# %% [markdown]
# ### Matrix $A^{-1}$
#
# Let's calculate SVD first:

# %%
U, s, V = svd(A)

# %% [markdown]
# Let's verify that $U S V = A$ and that $U^{-1} = U^T$ and $V^{-1} = V^T$:

# %%
print abs(dot(U, dot(diag(s), V))-A).max()
print abs(inv(U)-U.T).max()
print abs(inv(V)-V.T).max()
# Out:
# 8.10411491645e-15
# 2.10942374679e-15
# 2.88657986403e-15

# %% [markdown]
# Let's look at the singular values, you can see that the last one is zero:

# %%
s
# Out:
# array([  5.24779881e+00,   5.03969428e+00,   5.03969428e+00,
#          5.03969428e+00,   4.81718504e+00,   4.81718504e+00,
#          4.81718504e+00,   4.55111111e+00,   3.34958072e+00,
#          3.34958072e+00,   3.31851852e+00,   3.31851852e+00,
#          3.31851852e+00,   3.28555376e+00,   3.28555376e+00,
#          3.28555376e+00,   3.16129557e+00,   3.16129557e+00,
#          3.16129557e+00,   3.16129557e+00,   3.16129557e+00,
#          3.16129557e+00,   3.03407407e+00,   3.03407407e+00,
#          3.03407407e+00,   2.38874089e+00,   2.38874089e+00,
#          2.38874089e+00,   2.13333333e+00,   2.13333333e+00,
#          2.13333333e+00,   2.07407407e+00,   2.07407407e+00,
#          2.07407407e+00,   2.01481481e+00,   2.01481481e+00,
#          2.01481481e+00,   1.76139917e+00,   1.76139917e+00,
#          1.76139917e+00,   1.65301414e+00,   1.60314887e+00,
#          1.60314887e+00,   1.60314887e+00,   1.60314887e+00,
#          1.60314887e+00,   1.60314887e+00,   1.50967854e+00,
#          1.50967854e+00,   1.33333333e+00,   1.18518519e+00,
#          1.18518519e+00,   1.18518519e+00,   1.09223988e+00,
#          1.09223988e+00,   1.09223988e+00,   1.06666667e+00,
#          1.06666667e+00,   1.06666667e+00,   7.61853646e-01,
#          7.61853646e-01,   7.61853646e-01,   5.89557418e-01,
#          1.66274418e-14])

# %% [markdown]
# So the matrix $A$ can't be inverted. But we can calculate the pseudoinverse by inverting all the singular values and leaving the zero be:

# %%
s_inv = 1/s
s_inv[-1] = 0
s_inv
# Out:
# array([ 0.19055609,  0.19842473,  0.19842473,  0.19842473,  0.20759012,
#         0.20759012,  0.20759012,  0.21972656,  0.29854483,  0.29854483,
#         0.30133929,  0.30133929,  0.30133929,  0.3043627 ,  0.3043627 ,
#         0.3043627 ,  0.31632601,  0.31632601,  0.31632601,  0.31632601,
#         0.31632601,  0.31632601,  0.32958984,  0.32958984,  0.32958984,
#         0.41863059,  0.41863059,  0.41863059,  0.46875   ,  0.46875   ,
#         0.46875   ,  0.48214286,  0.48214286,  0.48214286,  0.49632353,
#         0.49632353,  0.49632353,  0.56773048,  0.56773048,  0.56773048,
#         0.6049555 ,  0.62377239,  0.62377239,  0.62377239,  0.62377239,
#         0.62377239,  0.62377239,  0.66239267,  0.66239267,  0.75      ,
#         0.84375   ,  0.84375   ,  0.84375   ,  0.9155498 ,  0.9155498 ,
#         0.9155498 ,  0.9375    ,  0.9375    ,  0.9375    ,  1.31258806,
#         1.31258806,  1.31258806,  1.69618763,  0.        ])

# %%
Apinv = dot(V.T, dot(diag(s_inv), U.T))

# %% [markdown]
# The pseudoinverse is "almost" an inverse --- when multiplied by $A$, the result is close to 1 at diagonal, and close to 0 everywhere else:

# %%
showmat(dot(Apinv, A))

# %% [markdown]
# Here is how the pseudoinverse looks like:

# %%
showmat(Apinv)
