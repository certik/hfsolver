# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
D = loadtxt("../H.pseudo.density")
R = D[0, :]
V = D[1, :]
Vd = D[2, :]
Vdd = D[3, :]
n = D[4, :]

# %%
plot(R, V)
plot(R, Vd)
plot(R, Vdd)

# %%
plot(R, n)
