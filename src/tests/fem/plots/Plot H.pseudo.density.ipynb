# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
D = loadtxt("../H.pseudo.density", skiprows=1)

# %%
R = D[0, :]
V = D[1, :]
Vd = D[2, :]
Vdd = D[3, :]
n = D[4, :]

# %%
plot(R, V)
plot(R, 1/R)
ylim([1, 7])
# Out:
# (1, 7)

# %%
from scipy.interpolate import splrep, splev
tck = splrep(R, V)
n_spline = -(splev(R, tck, der=2)+2/R*splev(R, tck, der=1))/(4*pi)

# %%
semilogx(R, n_spline)

# %%
semilogx(R, n_spline)
semilogx(R, n)

# %%
plot(R, n, "b-")
plot([R[-1], 1], [0, 0], "b-")
xlim([0, 1])
# Out:
# (0, 1)
