# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
D = loadtxt("ofmd_results.txt")

# %%
t  = D[1:, 0]
E1 = D[1:, 1]
E2 = D[1:, 2]
E3 = D[1:, 3]
E = E1+E2+E3

# %%
plot(t, E1)
plot(t, E2)
plot(t, E3)
plot(t, E)

# %%
plot(t, E1-E1.mean())
plot(t, E2-E2.mean())
plot(t, E3-E3.mean())
plot(t, E - E.mean())
