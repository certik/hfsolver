# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
D = loadtxt("ofmd_results.txt.1000")

# %%
t  = D[1:, 0]
N = 4
Ha2eV = 27.21138505
E1 = D[1:, 1]/N * Ha2eV
E2 = D[1:, 2]/N * Ha2eV
E3 = D[1:, 3]/N * Ha2eV
T = D[1:, 4]
E = E1+E2+E3

# %%
plot(t, E1)
plot(t, E2)
plot(t, E3)
plot(t, E)

# %%
plot(t, E1-E1.mean())
plot(t, E2-E2.mean())
plot(t, E3-E3.mean())
plot(t, E - E.mean())

# %%
plot(t, E)
