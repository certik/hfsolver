# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
D = loadtxt("../of_cond_lg.txt")
t_lg = D[:, 1]
cond_lg = D[:, 2:5]
Etot_lg = D[:, 5]

# %%
D = loadtxt("../of_cond_vg.txt")
t = D[:, 1]
cond = D[:, 2:5]
Etot = D[:, 5]

# %%
plot(t, cond[:, 0], label="velocity gauge")
plot(t, cond[:, 1])
plot(t, cond[:, 2])
plot(t_lg, cond_lg[:, 0], label="length gauge")
plot(t_lg, cond_lg[:, 1])
plot(t_lg, cond_lg[:, 2])
legend(loc="lower right")
xlabel("t [a.u.]")
ylabel("Current [a.u.]")
title("Length and Velocity Gauges Comparison")
savefig("length_velocity_gauges.pdf")
show()

# %%
plot(t, cond[:, 0]-cond_lg[:, 0])
xlabel("t [a.u.]")
ylabel("Error in Current [a.u.]")
title("Length and Velocity Gauges Difference")
savefig("length_velocity_gauges_difference.pdf")
show()
