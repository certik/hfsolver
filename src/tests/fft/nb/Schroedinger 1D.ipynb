# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
D = loadtxt("../sch1d.txt")
t = D[:, 1]
psi_norm = D[:, 2]
E_tot = D[:, 3]
#current = D[:, 4]
#Ex = D[:, 5]

# %%
D = loadtxt("../sch1d_grid.txt")
Xn = D[0, :]
Vn = D[1, :]

# %%
D = loadtxt("../sch1d_psi.txt")
Ng = D.shape[1]/2
psi = D[:, :Ng]+1j*D[:, Ng:]

# %%
plot(t, psi_norm-1)

# %%
figure(figsize=(16, 8))
#plot(Xn, Vn/10)
for i in range(0, psi.shape[0], psi.shape[0]/5):
    plot(Xn, abs(psi[i, :])**2, "-", label="psi i=%d" % i)
legend()
show()

# %%
semilogy(abs(E_tot-E_tot[-1]))

# %%
plot(Xn, Vn)

# %%
plot(t, current)
xlabel("t [a.u.]")
ylabel("current [a.u.]")
savefig("current_1d.pdf")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-85-563d6a667190> in <module>()
# ----> 1 plot(t, current)
#       2 xlabel("t [a.u.]")
#       3 ylabel("current [a.u.]")
#       4 savefig("current_1d.pdf")
#
# NameError: name 'current' is not defined
