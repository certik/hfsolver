# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
D = loadtxt("../enr.txt")
x = D[0,:]
V = D[1,:]
psi = D[2:,:]
psi0 = psi[0,:]
enr = psi0.copy()
s = 170
enr[s:] = -psi0[:-s]*0.7
enr[:-s] += -psi0[s:]*0.7
plot(x, enr)

D = loadtxt("../sch1d_psi.txt")
x2 = D[0,:]
psi2 = D[1:,:]
plot(x2, psi2[0,:])
xlim([0, 6])
show()
