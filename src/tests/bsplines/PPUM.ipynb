# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
n = 5
k = 4
D = loadtxt("ppum.txt", skiprows=1)

x = D[0, :]
Nb = (size(D, 0)-1)/3
Nq = size(D, 1)
B = empty((Nb, Nq))
Bp = empty((Nb, Nq))
Bpp = empty((Nb, Nq))

for i in range(Nb):
    B[i, :] = D[3*i+1, :]
    Bp[i, :] = D[3*i+2, :]
    Bpp[i, :] = D[3*i+3, :]

figure(figsize=(16, 4))
for i in range(Nb):
    suptitle("B-spline basis n=%d, k=%d" % (n, k), fontsize=14)
    subplot(131)
    plot(x, B[i, :], "k-")
    xlabel("$x$")
    ylabel("$B(x)$")
    subplot(132)
    plot(x, Bp[i, :], "k-")
    xlabel("$x$")
    ylabel("$B'(x)$")
    subplot(133)
    plot(x, Bpp[i, :], "k-")
    xlabel("$x$")
    ylabel("$B''(x)$")
